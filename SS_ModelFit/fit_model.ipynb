# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import tensorflow as tf
import keras_preprocessing
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator

# Training Set
TRAINING_DIR = "/gdrive/My Drive/Colab Notebooks/zugzwang/SS_ModelFit/01_train_validation_set/01_training/"
training_datagen = ImageDataGenerator(rescale = 1./255,
                                      #rotation_range=30,
                                      width_shift_range=0.1,
                                      height_shift_range=0.1,
                                      #shear_range=0.1,
                                      zoom_range=0.1,
                                      horizontal_flip=True,
                                      vertical_flip=True,
                                      fill_mode='nearest')
train_generator = training_datagen.flow_from_directory(TRAINING_DIR,
                                                       target_size=(50,50),
	                                                     class_mode='categorical',
                                                       batch_size=100)

# Validation Set
VALIDATION_DIR = "/gdrive/My Drive/Colab Notebooks/zugzwang/SS_ModelFit/01_train_validation_set/02_validation/"
validation_datagen = ImageDataGenerator(rescale = 1./255)
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
	                                                            target_size=(50,50),
	                                                            class_mode='categorical',
	                                                            batch_size=100)

# Define callback functions
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') > 0.9950):
      print("\nReached 99.50% accuracy so cancelling training!")
      self.model.stop_training = True

myCallbacksList = [myCallback()]

# Define model
model = tf.keras.models.Sequential([
    # Input shape = 50x50 RGB color image
    # 1st Convolutional Neural Network (CNN)
    tf.keras.layers.Conv2D(64, (3,3), activation=tf.nn.relu, input_shape=(50, 50, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    # 2nd Convolutional Neural Network (CNN)
    tf.keras.layers.Conv2D(64, (3,3), activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D(2,2),

    # 3rd Convolutional Neural Network (CNN)
    tf.keras.layers.Conv2D(128, (3,3), activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D(2,2),

    # 4th Convolutional Neural Network (CNN)
    tf.keras.layers.Conv2D(128, (3,3), activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D(2,2),

    # Flatten the results to feed into a Dense Neural Network (DNN)
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),

    # 512-neuron DNN
    tf.keras.layers.Dense(512, activation=tf.nn.relu),

    # Softmax Output Layer (3 categories)
    tf.keras.layers.Dense(3, activation=tf.nn.softmax)
])

model.summary()
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])
history = model.fit(x=train_generator,
                    epochs=1000,
                    validation_data=validation_generator,
                    verbose=2,
                    callbacks=myCallbacksList)

# Store trained model to h5 file
model_filename = "/gdrive/My Drive/Colab Notebooks/zugzwang/SS_ModelFit/02_trained_tf_models/model_13.h5"
#model_10 was best curve at epoch=~34
model.save(model_filename)
# Out:
# Found 800 images belonging to 3 classes.
# Found 544 images belonging to 3 classes.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 22, 22, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 327,747
# Trainable params: 327,747
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 8/8 - 196s - loss: 1.0637 - accuracy: 0.4750 - val_loss: 1.0128 - val_accuracy: 0.5129
# Epoch 2/1000
# 8/8 - 6s - loss: 0.9686 - accuracy: 0.5350 - val_loss: 0.7987 - val_accuracy: 0.6985
# Epoch 3/1000
# 8/8 - 7s - loss: 0.7758 - accuracy: 0.6525 - val_loss: 0.5453 - val_accuracy: 0.7298
# Epoch 4/1000
# 8/8 - 6s - loss: 0.5769 - accuracy: 0.7400 - val_loss: 0.5151 - val_accuracy: 0.6801
# Epoch 5/1000
# 8/8 - 6s - loss: 0.4591 - accuracy: 0.8213 - val_loss: 0.3567 - val_accuracy: 0.8566
# Epoch 6/1000
# 8/8 - 6s - loss: 0.4314 - accuracy: 0.8263 - val_loss: 0.4597 - val_accuracy: 0.7886
# Epoch 7/1000
# 8/8 - 6s - loss: 0.4611 - accuracy: 0.7987 - val_loss: 0.3654 - val_accuracy: 0.8695
# Epoch 8/1000
# 8/8 - 6s - loss: 0.3861 - accuracy: 0.8313 - val_loss: 0.2964 - val_accuracy: 0.9228
# Epoch 9/1000
# 8/8 - 6s - loss: 0.2468 - accuracy: 0.9362 - val_loss: 0.1625 - val_accuracy: 0.9485
# Epoch 10/1000
# 8/8 - 6s - loss: 0.1546 - accuracy: 0.9588 - val_loss: 0.1015 - val_accuracy: 0.9724
# Epoch 11/1000
# 8/8 - 6s - loss: 0.1982 - accuracy: 0.9337 - val_loss: 0.1384 - val_accuracy: 0.9485
# Epoch 12/1000
# 8/8 - 6s - loss: 0.1673 - accuracy: 0.9362 - val_loss: 0.2399 - val_accuracy: 0.9191
# Epoch 13/1000
# 8/8 - 6s - loss: 0.1317 - accuracy: 0.9700 - val_loss: 0.0599 - val_accuracy: 0.9908
# Epoch 14/1000
# 8/8 - 6s - loss: 0.0854 - accuracy: 0.9725 - val_loss: 0.0426 - val_accuracy: 0.9871
# Epoch 15/1000
# 8/8 - 6s - loss: 0.0612 - accuracy: 0.9787 - val_loss: 0.0206 - val_accuracy: 0.9945
# Epoch 16/1000
# 8/8 - 6s - loss: 0.0749 - accuracy: 0.9750 - val_loss: 0.0410 - val_accuracy: 0.9908
# Epoch 17/1000
# 8/8 - 6s - loss: 0.0964 - accuracy: 0.9700 - val_loss: 0.0504 - val_accuracy: 0.9890
# Epoch 18/1000
# 8/8 - 6s - loss: 0.0752 - accuracy: 0.9750 - val_loss: 0.0518 - val_accuracy: 0.9890
# Epoch 19/1000
# 8/8 - 6s - loss: 0.0485 - accuracy: 0.9875 - val_loss: 0.0123 - val_accuracy: 0.9963
# Epoch 20/1000
# 8/8 - 6s - loss: 0.0564 - accuracy: 0.9837 - val_loss: 0.0436 - val_accuracy: 0.9798
# Epoch 21/1000
# 8/8 - 6s - loss: 0.0534 - accuracy: 0.9825 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 22/1000
# 8/8 - 6s - loss: 0.0379 - accuracy: 0.9850 - val_loss: 0.0381 - val_accuracy: 0.9871
# Epoch 23/1000
# 8/8 - 6s - loss: 0.0226 - accuracy: 0.9937 - val_loss: 0.0135 - val_accuracy: 0.9945
# Epoch 24/1000
# 8/8 - 6s - loss: 0.0238 - accuracy: 0.9937 - val_loss: 0.0139 - val_accuracy: 0.9963
# Epoch 25/1000
# 8/8 - 6s - loss: 0.0171 - accuracy: 0.9912 - val_loss: 0.0196 - val_accuracy: 0.9926
# Epoch 26/1000
# 8/8 - 6s - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0335 - val_accuracy: 0.9908
# Epoch 27/1000
#
# Reached 99.50% accuracy so cancelling training!
# 8/8 - 6s - loss: 0.0166 - accuracy: 0.9962 - val_loss: 0.0104 - val_accuracy: 0.9963

# %%
# Plot Training vs. Validation accuracy with respect to number of epochs
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Plot Training vs. Validation loss with respect to number of epochs
import matplotlib.pyplot as plt
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Load model information
loaded_model = tf.keras.models.load_model(model_filename)

# Sample predictions
import numpy as np
from keras.preprocessing import image

# Predicting black pieces
img = image.load_img("/gdrive/My Drive/Colab Notebooks/zugzwang/SS_ModelFit/01_train_validation_set/02_validation/black/00-0-2.jpg", target_size=(50, 50))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
new_input = np.vstack([x])
prediction = np.round(loaded_model.predict(new_input))
print(prediction) # [[1. 0. 0.]]

# Predicting empty pieces
img = image.load_img("/gdrive/My Drive/Colab Notebooks/zugzwang/SS_ModelFit/01_train_validation_set/02_validation/empty/00-3-7.jpg", target_size=(50, 50))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
new_input = np.vstack([x])
prediction = np.round(loaded_model.predict(new_input))
print(prediction) # [[0. 1. 0.]]

# Predicting white pieces
img = image.load_img("/gdrive/My Drive/Colab Notebooks/zugzwang/SS_ModelFit/01_train_validation_set/02_validation/white/00-0-4.jpg", target_size=(50, 50))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
new_input = np.vstack([x])
prediction = np.round(loaded_model.predict(new_input))
print(prediction) # [[0. 0. 1.]]
# Out:
# Using TensorFlow backend.
# [[1. 0. 0.]]
# [[0. 0. 1.]]
# [[0. 0. 1.]]
